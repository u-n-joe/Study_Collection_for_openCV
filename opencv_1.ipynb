# %% [markdown]
# 1. .dtype = 속성값을 알아볼때
# 2. .astype = 타입을 바꿀때
#
# 3. 예시 (ndim, size, nbytes)
# tensor = [
#             [[1,2,5,8],[1,2,5,8],[1,2,5,8]],
#             [[1,2,5,8],[1,2,5,8],[1,2,5,8]],
#             [[1,2,5,8],[1,2,5,8],[1,2,5,8]],
#           ]
# np.array(tensor, int).ndim # 몇차원인지 반환
# np.array(tensor, int).size # 데이터의 사이즈 반환
# np.array(tensor, int).nbytes # 메모리 크기 반환

# %%
import cv2

# %%
import numpy as np
# 함수는 괄호 안에 쓴 숫자 개수만큼의 '0', '1', '비어있는 배열' 공간을 만들어줍니다.
img1 = np.empty((200, 300), dtype=np.uint8)#그레이스케일 이미지 크기만 할당하고 0또는1의 임의값을 넣어줌. 
img2 = np.zeros((200, 300, 3), dtype=np.uint8)#3은 채널의 갯수를 말한다. 칼라 이미지
img3 = np.ones((200, 300), dtype=np.uint8)*255 #그레이스케일 이미지. 흰바탕
img4 = np.full((200, 300, 3), (0, 255, 255), dtype=np.uint8) #3은 채널의 갯수를 말한다. 칼라 이미지의 노란바탕 
fname = 'img_yel.jpg'
cv2.imshow('img1', img1)
cv2.imshow('img2', img2)
cv2.imshow('img3', img3)
cv2.imshow('img4', img4)


cv2.waitKey(0)   #키보드 입력 대기. 입력한 키값 반환
cv2.destroyAllWindows()  #모든 윈도우 창 닫음

# %%
import cv2

fname = 'b.jpg'

original = cv2.imread(fname, cv2.IMREAD_COLOR) # .cv2.imread('파일경로', flag) = 이미지 입력
gray = cv2.imread(fname, cv2.IMREAD_GRAYSCALE)
unchange = cv2.imread(fname, cv2.IMREAD_UNCHANGED)

cv2.imshow('Original', original)
cv2.imshow('Gray', gray)
cv2.imshow('Unchange', unchange)

#cv2.waitKey(0)   #키보드 입력 대기. 입력한 키값 반환
#cv2.destroyAllWindows()  #모든 윈도우 창 닫음

# %%
import cv2

fname_o = 'b.jpg' # 파일 경로 가져옴
fname_t = 'b_gray2.jpg' # 파일 경로 설정 (저장될 파일 이름 및 경로)
gray = cv2.imread(fname_o, cv2.IMREAD_GRAYSCALE) # fname_o의 파일을 읽어서 그레이 컬러로 띄워준다.
cv2.imwrite(fname_t,gray) # imwrite함수에 저장 할 경로 및 파일이름 fname_t의 경로를 넣고 위에 리드한 이미지를 새로 써 넣는다
img = cv2.imread(fname_t)
cv2.imshow('image',img)
cv2.waitKey(0)   #키보드 입력 대기
cv2.destroyAllWindows()  #모든 윈도우 창 닫음

# %%
import cv2
from matplotlib import pyplot as plt 

# matplot에서는 RGB 순서이고,
# opencv에서는 BGR 순서이다.

img = cv2.imread('a.jpg', cv2.IMREAD_COLOR)
#opencv로 읽은 이미지를 matplot에 그대로 출력. 색상 반전됨
plt.imshow(img)
#plt.xticks([]) # x축 눈금
#plt.yticks([]) # y축 눈금
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt # as는 alias 적용시 사용

img = cv2.imread('a.jpg', cv2.IMREAD_COLOR)
window_name = 'Image'
#opencv로 읽은 이미지의 r,g,b순서를 뒤집어 배열 > 속도 저하로 비효율적이다, 그래서 cv2.cvtColor()을 사용하는게 효율적.
#b, g, r = cv2.split(img)   # img파일을 b,g,r로 분리
#img2 = cv2.merge([r,g,b]) # b,,g, r을 바꿔서 Merge
img4 = np.full((200, 300, 3), (0, 255, 255), dtype=np.uint8) #3은 채널의 갯수를 말한다. 칼라 이미지의 노란바탕
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  
# Displaying the image  
cv2.imshow(window_name, img4) 

plt.imshow(img2)
#plt.xticks([]) # x축 눈금
#plt.yticks([]) # y축 눈금
plt.show()

# %%
import cv2
import sys

cap = cv2.VideoCapture(0)#카메라 오픈

if not cap.isOpened():# cap.isOpen():카메라 정상오픈이면 True, 아니면 False
    print('카메라 오픈 안됨')
    sys.exit(0)

cap.set(3, 300) #카메라 영상의 가로 길이를 300으로 변경
cap.set(4, 200) #카메라 영상의 세로 길이를 200으로 변경

print('영상 가로 길이:', cap.get(3)) #cap.get(3):카메라 영상의 가로 길이 반환
print('영상 세로 길이:', cap.get(4)) #cap.get(4):카메라 영상의 세로 길이 반환

#카메라 영상 읽기. ret:처리결과(True, False) / frame:읽은 영상
ret, frame = cap.read() 

if ret:
    cv2.imwrite('pic1.jpg', frame) #카메라 영상 저장
    cv2.imshow('img', frame) #영상을 윈도우에 출력
    cv2.waitKey(0)
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 영상 가로 길이: 640.0
# 영상 세로 길이: 480.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-4db3d0281ddf> in <module>
#      20         cv2.imwrite('pic1.jpg', frame) #카메라 영상 저장
#      21         cv2.imshow('img', frame) #영상을 윈도우에 출력
# ---> 22         cv2.waitKey(0)
#      23         cap.release()
#      24         cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
# 동영상
import cv2
cap = cv2.VideoCapture(0)#카메라 오픈

cap.set(3, 300) 
cap.set(4, 200)
while True:
    ret, frame = cap.read() 
    if ret: #정상 읽기일 때만
        cv2.imshow('img', frame) #영상을 윈도우에 출력
    k = cv2.waitKey(1)
    if k==27: #입력한 키가 esc이면
        break
cap.release()
cv2.destroyAllWindows()

# %%
# 동영상 저장 
import cv2
cap = cv2.VideoCapture(0) #카메라 오픈
codec = cv2.VideoWriter_fourcc(*'DIVX') #사용할 코덱 생성
#동영상 작성자 객체 생성
out =  cv2.VideoWriter('a.avi', codec, 25.0, (640,480)) # (제목, 초당 25장을 찍음, 크기)
while cap.isOpened():	#카메라 정상 오픈일 때 동작
    ret, frame = cap.read() #카메라 영상 읽기
    if ret:#abs읽기가 정상이면
        out.write(frame)#동영상 작성
        cv2.imshow('frame', frame) #현재 frame을 윈도우에 출력
        if cv2.waitKey(1) & 0xFF == ord('q'): #q입력 시 종료 
            break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
# 찍은 영상 실행
import cv2
cap = cv2.VideoCapture('a.avi')#동영상 파일 오픈
while cap.isOpened():#동영상 파일이 정상 오픈이면
    ret, frame = cap.read()#동영상에서 frame을 읽음
    if not ret:
        break
    cv2.imshow('a.avi', frame)	#읽은 frame을 윈도우에 출력
    if cv2.waitKey(42) & 0xFF == ord('q'): #q입력 시 종료 
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img = np.full((512,512,3),(0,0,0), np.uint8)#검정 배경의 512x512의 이미지를 생성

#img에 (0,0)에서 (511,511)까지 흰색 선을 그림. 두께:5
img = cv2.line(img, (0,0), (511,511), (255,255,255), 5)

#img에 시작점(100,100), 끝점(300, 300)이고 빨간색 두께 10인 사각형
img = cv2.rectangle(img, (100,100), (300, 300), (0,0,255),10)

#img에 시작점(400,400), 반 지름, 연두색, 두께
img = cv2.circle(img, (400,400), 100 , (0, 255, 0), 5)

#선의 두께가 -1이면 안을 채움
#cv2.ellipse(img, center, axes, angle, startAngle, endAngle, color[, thickness[, lineType[, shift]]]) → img
#img – image
#center – 타원의 중심
#axes – 중심에서 가장 큰 거리와 작은 거리
#angle – 타원의 기울기 각
#startAngle – 타원의 시작 각도
#endAngle – 타원이 끝나는 각도
#color – 타원의 색
#thickness – 선 두께 -1이면 안쪽을 채움
img = cv2.ellipse(img, (250, 250), (100, 50), 0, 0, 180, (255,0,0), -1)

pts = np.array([[100,400],[0,500],[200, 500]], np.int32)
img = cv2.polylines(img, [pts], True, (100,100,100), 8)

img = cv2.putText(img, 'hello!', (50,150), cv2.FONT_HERSHEY_SIMPLEX, 4, 	(200,200,200), 5)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
events = [i for i in dir(cv2) if 'EVENT' in i]
events
# Out:
# ['EVENT_FLAG_ALTKEY',
#  'EVENT_FLAG_CTRLKEY',
#  'EVENT_FLAG_LBUTTON',
#  'EVENT_FLAG_MBUTTON',
#  'EVENT_FLAG_RBUTTON',
#  'EVENT_FLAG_SHIFTKEY',
#  'EVENT_LBUTTONDBLCLK',
#  'EVENT_LBUTTONDOWN',
#  'EVENT_LBUTTONUP',
#  'EVENT_MBUTTONDBLCLK',
#  'EVENT_MBUTTONDOWN',
#  'EVENT_MBUTTONUP',
#  'EVENT_MOUSEHWHEEL',
#  'EVENT_MOUSEMOVE',
#  'EVENT_MOUSEWHEEL',
#  'EVENT_RBUTTONDBLCLK',
#  'EVENT_RBUTTONDOWN',
#  'EVENT_RBUTTONUP']

# %%
import cv2
import numpy as np

# callback함수
# event = 발생한 이벤트 객체
# x, y = 이벤트 발생 위치
# flags : 플래그 정보
# param = cv2.setMouseCallback('image', draw_circle)
def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img,(x,y), 20,(255,0,0),10)
        cv2.imshow('image', img)

# 빈 Image 생성
img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image', draw_circle)

while(1):
    cv2.imshow('image', img)
    if cv2.waitKey(0) & 0xFF == 27:
       
        break
        
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np 

drawing = False #Mouse가 클릭된 상태 확인용
mode = True # True이면 사각형, false면 원
ix,iy = -1,-1


# Mouse Callback함수
def draw_square(event, x,y, flags, param):
    global ix,iy, drawing, mode

    if event == cv2.EVENT_LBUTTONDOWN: #마우스를 누른 상태
        drawing = True 
        ix, iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE: # 마우스 이동
        if drawing == True:            # 마우스를 누른 상태 일경우
            if mode == True:
                cv2.rectangle(img,(ix,iy),(x,y),(255,0,0),-1)
            else:
                cv2.circle(img,(x,y),5,(0,255,0),-1)

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False;             # 마우스를 때면 상태 변경
        if mode == True:
            cv2.rectangle(img,(ix,iy),(x,y),(255,0,0),-1)
        else:
            cv2.circle(img,(x,y),5,(0,255,0),-1)


img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_square)

while True:
    cv2.imshow('image', img)

    k = cv2.waitKey(1) & 0xFF

    if k == ord('m'):    # 사각형, 원 Mode변경
        mode = not mode
    elif k == 27:        # esc를 누르면 종료
        break

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np 

drawing = False #Mouse가 클릭된 상태 확인용
mode = True # True이면 사각형, false면 원
remove = False # True이면 지우개 생성.
ix,iy = -1,-1


# Mouse Callback함수

def draw_square(event, x,y, flags, param):
    global ix,iy, drawing, mode

    
    
    if event == cv2.EVENT_LBUTTONDOWN: #마우스를 누른 상태
        drawing = True 
        ix, iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE: # 마우스 이동
        if drawing == True:            # 마우스를 누른 상태 일경우
            if mode == True:
                cv2.rectangle(img,(ix,iy),(x,y),(255,0,0),-1)
            elif mode == False :
                cv2.circle(img,(x,y),5,(0,255,0),-1)
            elif remove == True:
                cv2.circle(img,(x,y),5,(0,0,0),-1)
            

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False;             # 마우스를 때면 상태 변경
        if mode == True:
            cv2.rectangle(img,(ix,iy),(x,y),(255,0,0),-1)
        elif mode == False :
            cv2.circle(img,(x,y),5,(0,255,0),-1)
        elif remove == True:
            cv2.circle(img,(x,y),5,(0,0,0),-1)
            
    if event == cv2.EVENT_RBUTTONDOWN: # 오른쪽 마우스 클릭시 원 생성
        drawing = True 
        ix, iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE: # 마우스 이동
        cv2.circle(img,(x,y), 20,(255,0,0),10)
        cv2.imshow('image', img)
        
    elif event == cv2.EVENT_RBUTTONUP:
        drawing = False;             # 마우스를 때면 상태 변경
        cv2.circle(img,(x,y), 20,(255,0,0),10)
        cv2.imshow('image', img)


img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_square)

while True:
    cv2.imshow('image', img)

    k = cv2.waitKey(1) & 0xFF

    if k == ord('m'):    # 사각형, 원 Mode변경
        mode = not mode
    elif k == ord('e'): # 지우개 모드
        remove = not remove      
    elif k == 27:        # esc를 누르면 종료
        break

cv2.destroyAllWindows()

##!!! 변경된 내용임. 지우개 구현해보기

# %%
import cv2
import numpy as np

def nothing(x):
    pass

img = np.zeros((300,512,3), np.uint8)
cv2.namedWindow('image')

# trackbar를 생성하여 named window에 등록
*cv2.createTrackbar(trackbarName, windowName, value, count, onChange) trackbarName – trackbar Name
cv2.createTrackbar('R', 'image', 0, 255, nothing)
cv2.createTrackbar('G', 'image', 0, 255, nothing)
cv2.createTrackbar('B', 'image', 0, 255, nothing) # nothing은 함수(핸들러)값을 말함.

switch = '0:OFF\n1:On'
cv2.createTrackbar(switch, 'image', 1, 1, nothing)

while(1):
    cv2.imshow('image', img)

    if cv2.waitKey(1) & 0xFF == 27:
        break

    r = cv2.getTrackbarPos('R','image')
    g = cv2.getTrackbarPos('G', 'image')
    b = cv2.getTrackbarPos('B', 'image')
    s = cv2.getTrackbarPos(switch, 'image')

    if s == 0:
        img[:] = 0 # 모든 행/열 좌표 값을 0으로 변경. 검은색
    else:
        img[:] = [b,g,r] # 모든 행/열 좌표값을 [b,g,r]로 변경

cv2.destroyAllWindows()
# Out:
#   File "<ipython-input-10-fc2944cf14b8>", line 11
#     *cv2.createTrackbar(trackbarName, windowName, value, count, onChange) trackbarName – trackbar Name
#                                                                                      ^
# SyntaxError: invalid syntax

# %%
import cv2
img = cv2.imread('a.jpg', 1)
# 위에서 불러온 이미지의 100,100의 RGB값을 가져옴.
p = img[100, 100]
list(p)
# Out:
# [202, 170, 97]

# %%
import cv2
img = cv2.imread('a.jpg', 1)
cv2.imshow("dd",img)
cv2.waitKey(0)   #키보드 입력 대기. 입력한 키값 반환
cv2.destroyAllWindows()  #모든 윈도우 창 닫음

# %%
img[100, 100] = [255,255,255]
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[:,:,2] = 255 # 
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[100, 100] = [255,255,255] # 100,100 위치를 흰색으로 변경.
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
p2 = img.item(100, 100, 2)
p2
# Out:
# 255

# %%
img.itemset((100, 100, 0), 0) # Itemset을 통해서 이미지의 부위색 변경
img.itemset((100, 100, 1), 0)
img.itemset((100, 100, 2), 0)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# img[x의 처음:x의끝 , y의 처음:y의 끝]
roi = img[100:200, 100:300] # 특정 영역만 추출해 낼수 있다.
cv2.imshow('roi', roi)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[0:100, 200:400] = roi #위에서 잘라낸 값을 img[0:100, 200:400] 해당 영역에 붙인다.
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt
imgb = cv2.imread('c.jpg', 1)
img_b=imgb[:,:,0]
img_g=imgb[:,:,1]
img_r=imgb[:,:,2]
#imgs = cv2.merge((img_b,img_g,img_r))
imgs = cv2.merge((img_r,img_g,img_b))
plt.imshow(imgs)
plt.show()

# %%
img[:,:,2] = 0  #이미지에서 빨간색 제거
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
src = cv2.imread('a.jpg')
img1 = src   #얕은 복사 소스를 공유해서 둘다 영향이 있음
img2 = src.copy()   #깊은 복사 >> 원본을 유지할수 있음
img1[100:200, 100:200, 2] = 255 # 빨강 필터를 입힌다. 
cv2.imshow('src', src)
cv2.imshow('img1', img1)
cv2.imshow('img2', img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
src = cv2.imread('c.jpg')
img1 = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(src, cv2.COLOR_BGR2RGB) # 색상 반전
img3 = cv2.cvtColor(img2, cv2.COLOR_RGB2BGR) # 반전된 이미지를 다시 원본으로 바꿈
cv2.imshow('src', src)
cv2.imshow('img1', img1)
cv2.imshow('img2', img2)
cv2.imshow('img3', img3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 사진 앱 만들기
# 기능
# 1. 사진 찍기
# 2. 동영상 찍기
# 3. 사진 앨범 보기
# 4. 동영상 보기

# %%
import cv2
import numpy as np 

drawing = False #Mouse가 클릭된 상태 확인용
mode = True # True이면 사각형, false면 원
ix,iy = -1,-1


# Mouse Callback함수
def draw_circle(event, x,y, flags, param):
    global ix,iy, drawing, mode

    if event == cv2.EVENT_LBUTTONDOWN: #마우스를 누른 상태
        drawing = True 
        ix, iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE: # 마우스 이동
        if drawing == True:            # 마우스를 누른 상태 일경우
            if mode == True:
                cv2.rectangle(img,(ix,iy),(x,y),(255,0,0),-1)
            else:
                cv2.circle(img,(x,y),5,(0,255,0),-1)

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False;             # 마우스를 때면 상태 변경
        if mode == True:
            cv2.rectangle(img,(ix,iy),(x,y),(255,0,0),-1)
        else:
            cv2.circle(img,(x,y),5,(0,255,0),-1)


img = np.zeros((512,512,3), np.uint8)
cv2.namedWindow('image')
cv2.setMouseCallback('image',draw_circle)

while True:
    cv2.imshow('image', img)

    k = cv2.waitKey(1) & 0xFF

    if k == ord('m'):    # 사각형, 원 Mode변경
        mode = not mode
    elif k == 27:        # esc를 누르면 종료
        break

cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

src = cv2.imread('c.jpg')#d.jpg 파일. src는 메모리에 저장된 배열
h, w, c = src.shape # src의 shape들을 각각저장해서
dst = np.full((h, w, c), [255,255,255], dtype=np.uint8) # 이와같이 흰색으로 만들어준다.

p0 = None # LBUTTONDOWN이벤트가 발생하는 지점. 복사할 영역 시작점.
p1 = None # LBUTTONUP이벤트가 발생하는 지점. 복사할 영역 끝점.
roi = None # p0 p1을 합친 점을 말한다. 리전오브이미지

cv2.imshow('src', src) # 이미지와 
cv2.imshow('dst', dst) # 흰판을 화면에 출력.

def handdler_src(event, x, y, flags, param):
    global p0, p1
    if event == cv2.EVENT_LBUTTONDOWN:
        p0 = (x, y) # 범위 설정 
    elif event == cv2.EVENT_LBUTTONUP:
        p1 = (x, y) # 범위 설정
        make_roi() # roi함수 호출
        
def make_roi():
    global roi
    roi = src[p0[1]:p1[1], p0[0]:p1[0]] # src[줄(p1[]),칸]
        
def handdler_dst(event, x, y, flags, param):
    global roi # 쓰는 이유는 roi에러를 막기위해 사용.
    if event == cv2.EVENT_LBUTTONDOWN:
        if roi is not None: # roi랑 같은 크기의 영역을 클릭한 위치에 넣는다
            h = np.abs(p0[1]-p1[1])
            w = np.abs(p0[0]-p1[0])
            dst[y:y+h, x:x+w] = roi
            cv2.imshow('dst', dst)
            roi = None

# 빈 Image 생성
cv2.setMouseCallback('src', handdler_src) # src창에서 마우스이벤트 발생하면 handdler_src 함수 실행
cv2.setMouseCallback('dst', handdler_dst) # dst창에서 마우스이벤트 발생하면 handdler_dst 함수 실행

while True:
    if cv2.waitKey(0) & 0xFF == 27: 
        break

cv2.waitKey(0)
cv2.destroyAllWindows()
